# %%
from Trafalgars import*

# %%
#for multiple stocks
graph_close(["^TNX", "AAPL", "TSLA"], "2016-01-01", "2021-01-01")

# %%
#graph_volume(stock, start_date, end_date)

#for multiple stocks
graph_volume(["^TNX", "AAPL", "TSLA"], "2016-01-01", "2021-01-01")
# Out:
# C:\Users\zarra\anaconda3\envs\pyvizn\lib\site-packages\pandas_datareader\base.py:272: SymbolWarning: Failed to read symbol: '^TNX', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
